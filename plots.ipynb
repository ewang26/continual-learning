# %%
import numpy as np
import matplotlib.pyplot as plt
import skimage
import os
from matplotlib.patches import Ellipse
import matplotlib.transforms as transforms
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import numpy as np
import pickle
import pandas as pd
import glob
from run import OUTPUT_DIR

# %%
# print(OUTPUT_DIR)
OUTPUT_DIR = 'mnist_cifar_zero_grad2'
# OUTPUT_DIR = 'test_cifar100'
# OUTPUT_DIR = 'GSS2'

#choose parameters to graph

task_no = 0 # this is the task that the accuracy graph will be displayed for
params = {'exp_name' : ['cifar10']} # parameters to display
# params = {'early_stopping_threshold': [100000]} # parameters to display

result_dir = 'plots'

# %%
def load_results():
    results = []
    for fname in glob.glob(f'{OUTPUT_DIR}/*/*'):
        # print('Reading from {}'.format(fname))
        if os.path.splitext(fname)[1] == '.pickle':  # Only try to unpickle .pickle files
            try:
                with open(fname, 'rb') as f:
                    result = pickle.load(f)
                    results.append(result)
            except (pickle.UnpicklingError, EOFError, AttributeError) as e:
                print(f"Error unpickling {fname}: {str(e)}")
        # else:
        #     print(f"Skipping non-pickle file: {fname}")
    
    df = pd.DataFrame(results)
    return df

results = load_results()
results
# Out:
#               RandomMemorySetManager memory selection  \
# 0   {'model performances': {'M2': 0.9599, 'M3': 0....
# 1   {'model performances': {'M2': 0.9588, 'M3': 0....
# 2   {'model performances': {'M2': 0.9619, 'M3': 0....
# 3   {'model performances': {'M2': 0.9599, 'M3': 0....
# 4   {'model performances': {'M2': 0.9581, 'M3': 0....
# ..                                                ...
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
# 98                                                NaN
# 99                                                NaN
#
#               KMeansMemorySetManager memory selection  \
# 0   {'model performances': {'M2': 0.9599, 'M3': 0....
# 1   {'model performances': {'M2': 0.9588, 'M3': 0....
# 2   {'model performances': {'M2': 0.9619, 'M3': 0....
# 3   {'model performances': {'M2': 0.9599, 'M3': 0....
# 4   {'model performances': {'M2': 0.9581, 'M3': 0....
# ..                                                ...
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
# 98                                                NaN
# 99                                                NaN
#
#               LambdaMemorySetManager memory selection  \
# 0   {'model performances': {'M2': 0.9599, 'M3': 0....
# 1   {'model performances': {'M2': 0.9588, 'M3': 0....
# 2   {'model performances': {'M2': 0.9619, 'M3': 0....
# 3   {'model performances': {'M2': 0.9599, 'M3': 0....
# 4   {'model performances': {'M2': 0.9581, 'M3': 0....
# ..                                                ...
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
# 98                                                NaN
# 99                                                NaN
#
#                        iCaRL memory selection (icarl)  \
# 0   {'model performances': {'M2': 0.9599, 'M3': 0....
# 1   {'model performances': {'M2': 0.9588, 'M3': 0....
# 2   {'model performances': {'M2': 0.9619, 'M3': 0....
# 3   {'model performances': {'M2': 0.9599, 'M3': 0....
# 4   {'model performances': {'M2': 0.9581, 'M3': 0....
# ..                                                ...
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
# 98                                                NaN
# 99                                                NaN
#
#                       iCaRL memory selection (replay) execution_time      p  \
# 0   {'model performances': {'M2': 0.9599, 'M3': 0....       02:58:39  0.002
# 1   {'model performances': {'M2': 0.9588, 'M3': 0....       07:54:24  0.900
# 2   {'model performances': {'M2': 0.9619, 'M3': 0....       03:18:34  0.050
# 3   {'model performances': {'M2': 0.9599, 'M3': 0....       03:02:08  0.010
# 4   {'model performances': {'M2': 0.9581, 'M3': 0....       03:05:45  0.020
# ..                                                ...            ...    ...
# 95                                                NaN       10:41:24  0.010
# 96                                                NaN       25:15:41  0.900
# 97                                                NaN       11:16:44  0.050
# 98                                                NaN       10:39:33  0.005
# 99                                                NaN       12:23:40  0.100
#
#     T  learning_rate  batch_size  ...  early_stopping_threshold  random_seed  \
# 0   5          0.001          50  ...                    100000            1
# 1   5          0.001          50  ...                    100000            3
# 2   5          0.001          50  ...                    100000            0
# 3   5          0.001          50  ...                    100000            1
# 4   5          0.001          50  ...                    100000            4
# .. ..            ...         ...  ...                       ...          ...
# 95  5          0.001          50  ...                   1000000            2
# 96  5          0.001          50  ...                   1000000            1
# 97  5          0.001          50  ...                   1000000            2
# 98  5          0.001          50  ...                   1000000            3
# 99  5          0.001          50  ...                   1000000            4
#
#     class_balanced  execute_early_stopping  exp_name  \
# 0             True                   False     mnist
# 1             True                   False     mnist
# 2             True                   False     mnist
# 3             True                   False     mnist
# 4             True                   False     mnist
# ..             ...                     ...       ...
# 95            True                   False   cifar10
# 96            True                   False   cifar10
# 97            True                   False   cifar10
# 98            True                   False   cifar10
# 99            True                   False   cifar10
#
#                                RandomMemorySetManager  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 95  {'model performances': {'M2': 0.6587, 'M3': 0....
# 96  {'model performances': {'M2': 0.6641, 'M3': 0....
# 97  {'model performances': {'M2': 0.6587, 'M3': 0....
# 98  {'model performances': {'M2': 0.6677, 'M3': 0....
# 99  {'model performances': {'M2': 0.6537, 'M3': 0....
#
#                                KMeansMemorySetManager  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 95  {'model performances': {'M2': 0.6587, 'M3': 0....
# 96  {'model performances': {'M2': 0.6641, 'M3': 0....
# 97  {'model performances': {'M2': 0.6587, 'M3': 0....
# 98  {'model performances': {'M2': 0.6677, 'M3': 0....
# 99  {'model performances': {'M2': 0.6537, 'M3': 0....
#
#                                LambdaMemorySetManager  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 95  {'model performances': {'M2': 0.6587, 'M3': 0....
# 96  {'model performances': {'M2': 0.6641, 'M3': 0....
# 97  {'model performances': {'M2': 0.6587, 'M3': 0....
# 98  {'model performances': {'M2': 0.6677, 'M3': 0....
# 99  {'model performances': {'M2': 0.6537, 'M3': 0....
#
#                                         iCaRL (icarl)  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 95  {'model performances': {'M2': 0.6587, 'M3': 0....
# 96  {'model performances': {'M2': 0.6641, 'M3': 0....
# 97  {'model performances': {'M2': 0.6587, 'M3': 0....
# 98  {'model performances': {'M2': 0.6677, 'M3': 0....
# 99  {'model performances': {'M2': 0.6537, 'M3': 0....
#
#                                        iCaRL (replay)
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 95  {'model performances': {'M2': 0.6587, 'M3': 0....
# 96  {'model performances': {'M2': 0.6641, 'M3': 0....
# 97  {'model performances': {'M2': 0.6587, 'M3': 0....
# 98  {'model performances': {'M2': 0.6677, 'M3': 0....
# 99  {'model performances': {'M2': 0.6537, 'M3': 0....
#
# [100 rows x 22 columns]

# %%
# for i in range(0, len(results)):
#     row = results.iloc[i]
#     print(row['p'])
#     print(row['RandomMemorySetManager'])
    # print(row['RandomMemorySetManager memory selection'])


for param, values in params.items():
    results = results[results[param].isin(values)]
results = results.reset_index(drop=True)
results
# Out:
#    RandomMemorySetManager memory selection  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# 5                                      NaN
# 6                                      NaN
# 7                                      NaN
# 13          50  ...                   1000000            1            True
# 14          50  ...                   1000000            0            True
# 15          50  ...                   1000000            1            True
# 16          50  ...                   1000000            0            True
# 17          50  ...                   1000000            1            True
# 18          50  ...                   1000000            4            True
# 19          50  ...                   1000000            0            True
# 20          50  ...                   1000000            4            True
# 21          50  ...                   1000000            2            True
# 22          50  ...                   1000000            3            True
# 23          50  ...                   1000000            1            True
# 24          50  ...                   1000000            2            True
# 25          50  ...                   1000000            3            True
# 26          50  ...                   1000000            2            True
# 27          50  ...                   1000000            0            True
# 28          50  ...                   1000000            4            True
# 29          50  ...                   1000000            3            True
# 30          50  ...                   1000000            1            True
# 31          50  ...                   1000000            4            True
# 32          50  ...                   1000000            4            True
# 33          50  ...                   1000000            0            True
# 34          50  ...                   1000000            0            True
# 35          50  ...                   1000000            2            True
# 36          50  ...                   1000000            3            True
# 37          50  ...                   1000000            3            True
# 38          50  ...                   1000000            2            True
# 39          50  ...                   1000000            1            True
# 40          50  ...                   1000000            3            True
# 41          50  ...                   1000000            1            True
# 42          50  ...                   1000000            0            True
# 43          50  ...                   1000000            3            True
# 44          50  ...                   1000000            2            True
# 45          50  ...                   1000000            2            True
# 46          50  ...                   1000000            1            True
# 47          50  ...                   1000000            2            True
# 48          50  ...                   1000000            3            True
# 49          50  ...                   1000000            4            True
#
#     execute_early_stopping  exp_name  \
# 0                    False   cifar10
# 1                    False   cifar10
# 2                    False   cifar10
# 3                    False   cifar10
# 4                    False   cifar10
# 5                    False   cifar10
# 6                    False   cifar10
# 7                    False   cifar10
# 8                    False   cifar10
# 9                    False   cifar10
# 10                   False   cifar10
# 11                   False   cifar10
# 12                   False   cifar10
# 13                   False   cifar10
# 14                   False   cifar10
# 15                   False   cifar10
# 16                   False   cifar10
# 17                   False   cifar10
# 18                   False   cifar10
# 19                   False   cifar10
# 20                   False   cifar10
# 21                   False   cifar10
# 22                   False   cifar10
# 23                   False   cifar10
# 24                   False   cifar10
# 25                   False   cifar10
# 26                   False   cifar10
# 27                   False   cifar10
# 28                   False   cifar10
# 29                   False   cifar10
# 30                   False   cifar10
# 31                   False   cifar10
# 32                   False   cifar10
# 33                   False   cifar10
# 34                   False   cifar10
# 35                   False   cifar10
# 36                   False   cifar10
# 37                   False   cifar10
# 38                   False   cifar10
# 39                   False   cifar10
# 40                   False   cifar10
# 41                   False   cifar10
# 42                   False   cifar10
# 43                   False   cifar10
# 44                   False   cifar10
# 45                   False   cifar10
# 46                   False   cifar10
# 47                   False   cifar10
# 48                   False   cifar10
# 49                   False   cifar10
#
#                                RandomMemorySetManager  \
# 0   {'model performances': {'M2': 0.6677, 'M3': 0....
# 1   {'model performances': {'M2': 0.6658, 'M3': 0....
# 2   {'model performances': {'M2': 0.6658, 'M3': 0....
# 3   {'model performances': {'M2': 0.6587, 'M3': 0....
# 4   {'model performances': {'M2': 0.6641, 'M3': 0....
# 5   {'model performances': {'M2': 0.6658, 'M3': 0....
# 6   {'model performances': {'M2': 0.6587, 'M3': 0....
# 7   {'model performances': {'M2': 0.6641, 'M3': 0....
# 8   {'model performances': {'M2': 0.6537, 'M3': 0....
# 9   {'model performances': {'M2': 0.6677, 'M3': 0....
# 10  {'model performances': {'M2': 0.6537, 'M3': 0....
# 11  {'model performances': {'M2': 0.6537, 'M3': 0....
# 12  {'model performances': {'M2': 0.6537, 'M3': 0....
# 13  {'model performances': {'M2': 0.6641, 'M3': 0....
# 14  {'model performances': {'M2': 0.6658, 'M3': 0....
# 15  {'model performances': {'M2': 0.6641, 'M3': 0....
# 16  {'model performances': {'M2': 0.6658, 'M3': 0....
# 17  {'model performances': {'M2': 0.6641, 'M3': 0....
# 18  {'model performances': {'M2': 0.6537, 'M3': 0....
# 19  {'model performances': {'M2': 0.6658, 'M3': 0....
# 20  {'model performances': {'M2': 0.6537, 'M3': 0....
# 21  {'model performances': {'M2': 0.6587, 'M3': 0....
# 22  {'model performances': {'M2': 0.6677, 'M3': 0....
# 23  {'model performances': {'M2': 0.6641, 'M3': 0....
# 24  {'model performances': {'M2': 0.6587, 'M3': 0....
# 25  {'model performances': {'M2': 0.6677, 'M3': 0....
# 26  {'model performances': {'M2': 0.6587, 'M3': 0....
# 27  {'model performances': {'M2': 0.6658, 'M3': 0....
# 28  {'model performances': {'M2': 0.6537, 'M3': 0....
# 29  {'model performances': {'M2': 0.6677, 'M3': 0....
# 30  {'model performances': {'M2': 0.6641, 'M3': 0....
# 31  {'model performances': {'M2': 0.6537, 'M3': 0....
# 32  {'model performances': {'M2': 0.6537, 'M3': 0....
# 33  {'model performances': {'M2': 0.6658, 'M3': 0....
# 34  {'model performances': {'M2': 0.6658, 'M3': 0....
# 35  {'model performances': {'M2': 0.6587, 'M3': 0....
# 36  {'model performances': {'M2': 0.6677, 'M3': 0....
# 37  {'model performances': {'M2': 0.6677, 'M3': 0....
# 38  {'model performances': {'M2': 0.6587, 'M3': 0....
# 39  {'model performances': {'M2': 0.6641, 'M3': 0....
# 40  {'model performances': {'M2': 0.6677, 'M3': 0....
# 41  {'model performances': {'M2': 0.6641, 'M3': 0....
# 42  {'model performances': {'M2': 0.6658, 'M3': 0....
# 43  {'model performances': {'M2': 0.6677, 'M3': 0....
# 44  {'model performances': {'M2': 0.6587, 'M3': 0....
# 45  {'model performances': {'M2': 0.6587, 'M3': 0....
# 46  {'model performances': {'M2': 0.6641, 'M3': 0....
# 47  {'model performances': {'M2': 0.6587, 'M3': 0....
# 48  {'model performances': {'M2': 0.6677, 'M3': 0....
# 49  {'model performances': {'M2': 0.6537, 'M3': 0....
#
#                                KMeansMemorySetManager  \
# 0   {'model performances': {'M2': 0.6677, 'M3': 0....
# 1   {'model performances': {'M2': 0.6658, 'M3': 0....
# 2   {'model performances': {'M2': 0.6658, 'M3': 0....
# 3   {'model performances': {'M2': 0.6587, 'M3': 0....
# 4   {'model performances': {'M2': 0.6641, 'M3': 0....
# 5   {'model performances': {'M2': 0.6658, 'M3': 0....
# 6   {'model performances': {'M2': 0.6587, 'M3': 0....
# 7   {'model performances': {'M2': 0.6641, 'M3': 0....
# 8   {'model performances': {'M2': 0.6537, 'M3': 0....
# 9   {'model performances': {'M2': 0.6677, 'M3': 0....
# 10  {'model performances': {'M2': 0.6537, 'M3': 0....
# 11  {'model performances': {'M2': 0.6537, 'M3': 0....
# 12  {'model performances': {'M2': 0.6537, 'M3': 0....
# 13  {'model performances': {'M2': 0.6641, 'M3': 0....
# 14  {'model performances': {'M2': 0.6658, 'M3': 0....
# 15  {'model performances': {'M2': 0.6641, 'M3': 0....
# 16  {'model performances': {'M2': 0.6658, 'M3': 0....
# 17  {'model performances': {'M2': 0.6641, 'M3': 0....
# 18  {'model performances': {'M2': 0.6537, 'M3': 0....
# 19  {'model performances': {'M2': 0.6658, 'M3': 0....
# 20  {'model performances': {'M2': 0.6537, 'M3': 0....
# 21  {'model performances': {'M2': 0.6587, 'M3': 0....
# 22  {'model performances': {'M2': 0.6677, 'M3': 0....
# 23  {'model performances': {'M2': 0.6641, 'M3': 0....
# 24  {'model performances': {'M2': 0.6587, 'M3': 0....
# 25  {'model performances': {'M2': 0.6677, 'M3': 0....
# 26  {'model performances': {'M2': 0.6587, 'M3': 0....
# 27  {'model performances': {'M2': 0.6658, 'M3': 0....
# 28  {'model performances': {'M2': 0.6537, 'M3': 0....
# 29  {'model performances': {'M2': 0.6677, 'M3': 0....
# 30  {'model performances': {'M2': 0.6641, 'M3': 0....
# 31  {'model performances': {'M2': 0.6537, 'M3': 0....
# 32  {'model performances': {'M2': 0.6537, 'M3': 0....
# 33  {'model performances': {'M2': 0.6658, 'M3': 0....
# 34  {'model performances': {'M2': 0.6658, 'M3': 0....
# 35  {'model performances': {'M2': 0.6587, 'M3': 0....
# 36  {'model performances': {'M2': 0.6677, 'M3': 0....
# 37  {'model performances': {'M2': 0.6677, 'M3': 0....
# 38  {'model performances': {'M2': 0.6587, 'M3': 0....
# 39  {'model performances': {'M2': 0.6641, 'M3': 0....
# 40  {'model performances': {'M2': 0.6677, 'M3': 0....
# 41  {'model performances': {'M2': 0.6641, 'M3': 0....
# 42  {'model performances': {'M2': 0.6658, 'M3': 0....
# 43  {'model performances': {'M2': 0.6677, 'M3': 0....
# 44  {'model performances': {'M2': 0.6587, 'M3': 0....
# 45  {'model performances': {'M2': 0.6587, 'M3': 0....
# 46  {'model performances': {'M2': 0.6641, 'M3': 0....
# 47  {'model performances': {'M2': 0.6587, 'M3': 0....
# 48  {'model performances': {'M2': 0.6677, 'M3': 0....
# 49  {'model performances': {'M2': 0.6537, 'M3': 0....
#
#                                LambdaMemorySetManager  \
# 0   {'model performances': {'M2': 0.6677, 'M3': 0....
# 1   {'model performances': {'M2': 0.6658, 'M3': 0....
# 2   {'model performances': {'M2': 0.6658, 'M3': 0....
# 3   {'model performances': {'M2': 0.6587, 'M3': 0....
# 4   {'model performances': {'M2': 0.6641, 'M3': 0....
# 5   {'model performances': {'M2': 0.6658, 'M3': 0....
# 6   {'model performances': {'M2': 0.6587, 'M3': 0....
# 7   {'model performances': {'M2': 0.6641, 'M3': 0....
# 8   {'model performances': {'M2': 0.6537, 'M3': 0....
# 9   {'model performances': {'M2': 0.6677, 'M3': 0....
# 10  {'model performances': {'M2': 0.6537, 'M3': 0....
# 11  {'model performances': {'M2': 0.6537, 'M3': 0....
# 12  {'model performances': {'M2': 0.6537, 'M3': 0....
# 13  {'model performances': {'M2': 0.6641, 'M3': 0....
# 14  {'model performances': {'M2': 0.6658, 'M3': 0....
# 15  {'model performances': {'M2': 0.6641, 'M3': 0....
# 16  {'model performances': {'M2': 0.6658, 'M3': 0....
# 17  {'model performances': {'M2': 0.6641, 'M3': 0....
# 18  {'model performances': {'M2': 0.6537, 'M3': 0....
# 19  {'model performances': {'M2': 0.6658, 'M3': 0....
# 20  {'model performances': {'M2': 0.6537, 'M3': 0....
# 21  {'model performances': {'M2': 0.6587, 'M3': 0....
# 22  {'model performances': {'M2': 0.6677, 'M3': 0....
# 23  {'model performances': {'M2': 0.6641, 'M3': 0....
# 24  {'model performances': {'M2': 0.6587, 'M3': 0....
# 25  {'model performances': {'M2': 0.6677, 'M3': 0....
# 26  {'model performances': {'M2': 0.6587, 'M3': 0....
# 27  {'model performances': {'M2': 0.6658, 'M3': 0....
# 28  {'model performances': {'M2': 0.6537, 'M3': 0....
# 29  {'model performances': {'M2': 0.6677, 'M3': 0....
# 30  {'model performances': {'M2': 0.6641, 'M3': 0....
# 31  {'model performances': {'M2': 0.6537, 'M3': 0....
# 32  {'model performances': {'M2': 0.6537, 'M3': 0....
# 33  {'model performances': {'M2': 0.6658, 'M3': 0....
# 34  {'model performances': {'M2': 0.6658, 'M3': 0....
# 35  {'model performances': {'M2': 0.6587, 'M3': 0....
# 36  {'model performances': {'M2': 0.6677, 'M3': 0....
# 37  {'model performances': {'M2': 0.6677, 'M3': 0....
# 38  {'model performances': {'M2': 0.6587, 'M3': 0....
# 39  {'model performances': {'M2': 0.6641, 'M3': 0....
# 40  {'model performances': {'M2': 0.6677, 'M3': 0....
# 41  {'model performances': {'M2': 0.6641, 'M3': 0....
# 42  {'model performances': {'M2': 0.6658, 'M3': 0....
# 43  {'model performances': {'M2': 0.6677, 'M3': 0....
# 44  {'model performances': {'M2': 0.6587, 'M3': 0....
# 45  {'model performances': {'M2': 0.6587, 'M3': 0....
# 46  {'model performances': {'M2': 0.6641, 'M3': 0....
# 47  {'model performances': {'M2': 0.6587, 'M3': 0....
# 48  {'model performances': {'M2': 0.6677, 'M3': 0....
# 49  {'model performances': {'M2': 0.6537, 'M3': 0....
#
#                                         iCaRL (icarl)  \
# 0   {'model performances': {'M2': 0.6677, 'M3': 0....
# 1   {'model performances': {'M2': 0.6658, 'M3': 0....
# 2   {'model performances': {'M2': 0.6658, 'M3': 0....
# 3   {'model performances': {'M2': 0.6587, 'M3': 0....
# 4   {'model performances': {'M2': 0.6641, 'M3': 0....
# 5   {'model performances': {'M2': 0.6658, 'M3': 0....
# 6   {'model performances': {'M2': 0.6587, 'M3': 0....
# 7   {'model performances': {'M2': 0.6641, 'M3': 0....
# 8   {'model performances': {'M2': 0.6537, 'M3': 0....
# 9   {'model performances': {'M2': 0.6677, 'M3': 0....
# 10  {'model performances': {'M2': 0.6537, 'M3': 0....
# 11  {'model performances': {'M2': 0.6537, 'M3': 0....
# 12  {'model performances': {'M2': 0.6537, 'M3': 0....
# 13  {'model performances': {'M2': 0.6641, 'M3': 0....
# 14  {'model performances': {'M2': 0.6658, 'M3': 0....
# 15  {'model performances': {'M2': 0.6641, 'M3': 0....
# 16  {'model performances': {'M2': 0.6658, 'M3': 0....
# 17  {'model performances': {'M2': 0.6641, 'M3': 0....
# 18  {'model performances': {'M2': 0.6537, 'M3': 0....
# 19  {'model performances': {'M2': 0.6658, 'M3': 0....
# 20  {'model performances': {'M2': 0.6537, 'M3': 0....
# 21  {'model performances': {'M2': 0.6587, 'M3': 0....
# 22  {'model performances': {'M2': 0.6677, 'M3': 0....
# 23  {'model performances': {'M2': 0.6641, 'M3': 0....
# 24  {'model performances': {'M2': 0.6587, 'M3': 0....
# 25  {'model performances': {'M2': 0.6677, 'M3': 0....
# 26  {'model performances': {'M2': 0.6587, 'M3': 0....
# 27  {'model performances': {'M2': 0.6658, 'M3': 0....
# 28  {'model performances': {'M2': 0.6537, 'M3': 0....
# 29  {'model performances': {'M2': 0.6677, 'M3': 0....
# 30  {'model performances': {'M2': 0.6641, 'M3': 0....
# 31  {'model performances': {'M2': 0.6537, 'M3': 0....
# 32  {'model performances': {'M2': 0.6537, 'M3': 0....
# 33  {'model performances': {'M2': 0.6658, 'M3': 0....
# 34  {'model performances': {'M2': 0.6658, 'M3': 0....
# 35  {'model performances': {'M2': 0.6587, 'M3': 0....
# 36  {'model performances': {'M2': 0.6677, 'M3': 0....
# 37  {'model performances': {'M2': 0.6677, 'M3': 0....
# 38  {'model performances': {'M2': 0.6587, 'M3': 0....
# 39  {'model performances': {'M2': 0.6641, 'M3': 0....
# 40  {'model performances': {'M2': 0.6677, 'M3': 0....
# 41  {'model performances': {'M2': 0.6641, 'M3': 0....
# 42  {'model performances': {'M2': 0.6658, 'M3': 0....
# 43  {'model performances': {'M2': 0.6677, 'M3': 0....
# 44  {'model performances': {'M2': 0.6587, 'M3': 0....
# 45  {'model performances': {'M2': 0.6587, 'M3': 0....
# 46  {'model performances': {'M2': 0.6641, 'M3': 0....
# 47  {'model performances': {'M2': 0.6587, 'M3': 0....
# 48  {'model performances': {'M2': 0.6677, 'M3': 0....
# 49  {'model performances': {'M2': 0.6537, 'M3': 0....
#
#                                        iCaRL (replay)
# 0   {'model performances': {'M2': 0.6677, 'M3': 0....
# 1   {'model performances': {'M2': 0.6658, 'M3': 0....
# 2   {'model performances': {'M2': 0.6658, 'M3': 0....
# 3   {'model performances': {'M2': 0.6587, 'M3': 0....
# 4   {'model performances': {'M2': 0.6641, 'M3': 0....
# 5   {'model performances': {'M2': 0.6658, 'M3': 0....
# 6   {'model performances': {'M2': 0.6587, 'M3': 0....
# 7   {'model performances': {'M2': 0.6641, 'M3': 0....
# 8   {'model performances': {'M2': 0.6537, 'M3': 0....
# 9   {'model performances': {'M2': 0.6677, 'M3': 0....
# 10  {'model performances': {'M2': 0.6537, 'M3': 0....
# 11  {'model performances': {'M2': 0.6537, 'M3': 0....
# 12  {'model performances': {'M2': 0.6537, 'M3': 0....
# 13  {'model performances': {'M2': 0.6641, 'M3': 0....
# 14  {'model performances': {'M2': 0.6658, 'M3': 0....
# 15  {'model performances': {'M2': 0.6641, 'M3': 0....
# 16  {'model performances': {'M2': 0.6658, 'M3': 0....
# 17  {'model performances': {'M2': 0.6641, 'M3': 0....
# 18  {'model performances': {'M2': 0.6537, 'M3': 0....
# 19  {'model performances': {'M2': 0.6658, 'M3': 0....
# 20  {'model performances': {'M2': 0.6537, 'M3': 0....
# 21  {'model performances': {'M2': 0.6587, 'M3': 0....
# 22  {'model performances': {'M2': 0.6677, 'M3': 0....
# 23  {'model performances': {'M2': 0.6641, 'M3': 0....
# 24  {'model performances': {'M2': 0.6587, 'M3': 0....
# 25  {'model performances': {'M2': 0.6677, 'M3': 0....
# 26  {'model performances': {'M2': 0.6587, 'M3': 0....
# 27  {'model performances': {'M2': 0.6658, 'M3': 0....
# 28  {'model performances': {'M2': 0.6537, 'M3': 0....
# 29  {'model performances': {'M2': 0.6677, 'M3': 0....
# 30  {'model performances': {'M2': 0.6641, 'M3': 0....
# 31  {'model performances': {'M2': 0.6537, 'M3': 0....
# 32  {'model performances': {'M2': 0.6537, 'M3': 0....
# 33  {'model performances': {'M2': 0.6658, 'M3': 0....
# 34  {'model performances': {'M2': 0.6658, 'M3': 0....
# 35  {'model performances': {'M2': 0.6587, 'M3': 0....
# 36  {'model performances': {'M2': 0.6677, 'M3': 0....
# 37  {'model performances': {'M2': 0.6677, 'M3': 0....
# 38  {'model performances': {'M2': 0.6587, 'M3': 0....
# 39  {'model performances': {'M2': 0.6641, 'M3': 0....
# 40  {'model performances': {'M2': 0.6677, 'M3': 0....
# 41  {'model performances': {'M2': 0.6641, 'M3': 0....
# 42  {'model performances': {'M2': 0.6658, 'M3': 0....
# 43  {'model performances': {'M2': 0.6677, 'M3': 0....
# 44  {'model performances': {'M2': 0.6587, 'M3': 0....
# 45  {'model performances': {'M2': 0.6587, 'M3': 0....
# 46  {'model performances': {'M2': 0.6641, 'M3': 0....
# 47  {'model performances': {'M2': 0.6587, 'M3': 0....
# 48  {'model performances': {'M2': 0.6677, 'M3': 0....
# 49  {'model performances': {'M2': 0.6537, 'M3': 0....
#
# [50 rows x 22 columns]

# %%
def get_metric(df, p_val, method, metric):
    #returns the average and std for a given metric 
    p_value_df = df[df["p"] == p_val].reset_index(drop=True)
    method_metrics = p_value_df[method]
    metric_values = []
    for i in range(0, len(method_metrics)):         
         if metric == "Accuracy":
            metric_values.append(method_metrics[i]['M3 per task performance'][task_no])

         if metric == "M2 similarity":
             metric_values.append(method_metrics[i]['gradient similarities']['M2'])

         if metric == "M1 similarity":
             metric_values.append(method_metrics[i]['gradient similarities']['M1'])
             
    return metric_values

def get_metric_stats(metric_values):
    n = len(metric_values)
    return np.average(metric_values), np.std(metric_values)/np.sqrt(n)

def aggregate_results(results):

    #get method names

    colnames = results.columns
    colnames_list = colnames.tolist()

    if params['exp_name'] == ['mnist']:
        try:
            execution_time_index = colnames_list.index('execution_time')
        except ValueError:
            try:
                # If 'execution_time' is not found, look for 'execute_early_stopping'
                execution_time_index = colnames_list.index('execute_early_stopping')
            except ValueError:
                # If neither is found, use all column names
                execution_time_index = len(colnames_list)
        methods = colnames_list[:execution_time_index]
    
    else:
        # For non-mnist cases, get all columns after 'exp_name' until 'execution_time' or 'p'
        try:
            exp_name_index = colnames_list.index('exp_name')
            try:
                execution_time_index = colnames_list.index('execution_time', exp_name_index)
            except ValueError:
                try:
                    execution_time_index = colnames_list.index('p', exp_name_index)
                except ValueError:
                    execution_time_index = len(colnames_list)
            methods = colnames_list[exp_name_index + 1:execution_time_index]
        except ValueError:
            # If 'exp_name' is not found, use all columns
            methods = colnames_list

    method_names = methods

    # methods = ['RandomMemorySetManager']
    method_names = methods

    metrics = ["Accuracy", "M1 similarity", "M2 similarity"]
    
    unique_p_values = results['p'].unique()
    
    processed_data = []
    
    for p in unique_p_values:
        for method, method_name in zip(methods, method_names):
            filtered_data = results[(results['p'] == p) & (results[method].notna())]
            
            if not filtered_data.empty:
                row_data = {
                    'p': p,
                    'method': method_name,
                    'samples': len(filtered_data)
                }
                
                for metric in metrics:
                    metric_values = get_metric(filtered_data, p, method, metric)
                    avg, std = get_metric_stats(metric_values)
                    
                    if metric == "Accuracy":
                        row_data['M3_task_avg'] = avg
                        row_data['M3_task_std'] = std
                        row_data['M3_task_array'] = metric_values
                    elif metric == "M1 similarity":
                        row_data['M1_grad_sim_avg'] = avg
                        row_data['M1_grad_sim_std'] = std
                        row_data['M1_grad_sim_array'] = metric_values
                    elif metric == "M2 similarity":
                        row_data['M2_grad_sim_avg'] = avg
                        row_data['M2_grad_sim_std'] = std
                        row_data['M2_grad_sim_array'] = metric_values
                
                processed_data.append(row_data)
    
    processed_df = pd.DataFrame(processed_data)
    
    return processed_df

# %%
aggregated_results = aggregate_results(results)
aggregated_results
# Out:
#         p                  method  samples  M3_task_avg  M3_task_std  \
# 0   0.900  RandomMemorySetManager        5       0.7676     0.009468
# 1   0.900  KMeansMemorySetManager        5       0.7484     0.015013
# 2   0.900  LambdaMemorySetManager        5       0.7627     0.004410
# 3   0.900           iCaRL (icarl)        5       0.7605     0.006603
# 4   0.900          iCaRL (replay)        5       0.7486     0.008729
# 5   0.500  RandomMemorySetManager        5       0.6922     0.023024
# 6   0.500  KMeansMemorySetManager        5       0.7166     0.011248
# 7   0.500  LambdaMemorySetManager        5       0.7318     0.007114
# 8   0.500           iCaRL (icarl)        5       0.7147     0.005549
# 9   0.500          iCaRL (replay)        5       0.7509     0.008406
# 10  0.200  RandomMemorySetManager        5       0.5066     0.024279
# 11  0.200  KMeansMemorySetManager        5       0.5309     0.019199
# 12  0.200  LambdaMemorySetManager        5       0.5479     0.025154
# 13  0.200           iCaRL (icarl)        5       0.5713     0.012129
# 14  0.200          iCaRL (replay)        5       0.5941     0.009714
# 15  0.005  RandomMemorySetManager        5       0.0062     0.001246
# 16  0.005  KMeansMemorySetManager        5       0.0146     0.001977
# 17  0.005  LambdaMemorySetManager        5       0.0048     0.001604
# 18  0.005           iCaRL (icarl)        5       0.0086     0.001615
# 19  0.005          iCaRL (replay)        5       0.0119     0.001774
# 20  0.020  RandomMemorySetManager        5       0.0832     0.008864
# 21  0.020  KMeansMemorySetManager        5       0.0927     0.007337
# 22  0.020  LambdaMemorySetManager        5       0.1046     0.016319
# 23  0.020           iCaRL (icarl)        5       0.1015     0.020086
# 24  0.020          iCaRL (replay)        5       0.1042     0.011651
# 25  0.001  RandomMemorySetManager        5       0.0003     0.000110
# 26  0.001  KMeansMemorySetManager        5       0.0001     0.000089
# 27  0.001  LambdaMemorySetManager        5       0.0002     0.000110
# 28  0.001           iCaRL (icarl)        5       0.0008     0.000363
# 29  0.001          iCaRL (replay)        5       0.0007     0.000303
# 30  0.100  RandomMemorySetManager        5       0.3858     0.016084
# 31  0.100  KMeansMemorySetManager        5       0.3753     0.013048
# 32  0.100  LambdaMemorySetManager        5       0.3283     0.020484
# 33  0.100           iCaRL (icarl)        5       0.4043     0.020524
# 34  0.100          iCaRL (replay)        5       0.4784     0.015063
# 35  0.050  RandomMemorySetManager        5       0.2167     0.013922
# 36  0.050  KMeansMemorySetManager        5       0.2291     0.023831
# 37  0.050  LambdaMemorySetManager        5       0.1947     0.021938
# 38  0.050           iCaRL (icarl)        5       0.2546     0.028602
# 39  0.050          iCaRL (replay)        5       0.3003     0.010884
# 40  0.002  RandomMemorySetManager        5       0.0017     0.000610
# 41  0.002  KMeansMemorySetManager        5       0.0019     0.000654
# 42  0.002  LambdaMemorySetManager        5       0.0005     0.000346
# 43  0.002           iCaRL (icarl)        5       0.0015     0.000490
# 44  0.002          iCaRL (replay)        5       0.0021     0.000385
# 45  0.010  RandomMemorySetManager        5       0.0184     0.001670
# 46  0.010  KMeansMemorySetManager        5       0.0419     0.005287
# 47  0.010  LambdaMemorySetManager        5       0.0357     0.008083
# 48  0.010           iCaRL (icarl)        5       0.0366     0.006052
# 49  0.010          iCaRL (replay)        5       0.0315     0.003314
#
#                               M3_task_array  M1_grad_sim_avg  M1_grad_sim_std  \
# 0   [0.7665, 0.7475, 0.7465, 0.8045, 0.773]         0.993427         0.001402
# 1     [0.714, 0.777, 0.7025, 0.7645, 0.784]         0.985912         0.001956
# 2    [0.759, 0.7755, 0.747, 0.7705, 0.7615]         0.999067         0.000224
# 3      [0.785, 0.7635, 0.749, 0.742, 0.763]         0.991804         0.001768
# 4     [0.769, 0.7485, 0.762, 0.751, 0.7125]         0.990260         0.002338
# 5   [0.6615, 0.6415, 0.702, 0.7875, 0.6685]         0.952494         0.006600
# 6     [0.751, 0.733, 0.7065, 0.716, 0.6765]         0.888091         0.014526
# 7     [0.758, 0.7245, 0.726, 0.7395, 0.711]         0.987240         0.002102
# 8      [0.723, 0.691, 0.7155, 0.726, 0.718]         0.955809         0.008740
# 9    [0.7795, 0.747, 0.7345, 0.7645, 0.729]         0.947417         0.009828
# 10  [0.5685, 0.443, 0.4445, 0.5165, 0.5605]         0.842916         0.021410
# 34         0.046804  [0.5877296483268175, 0.8487934099137231, 0.548...
# 35         0.044360  [0.7261264068858413, 0.5068379604829816, 0.584...
# 36         0.060300  [0.2579910844422884, 0.5605365256399161, 0.648...
# 37         0.017788  [0.7487953505118488, 0.7282292628843948, 0.734...
# 38         0.045140  [0.5726007364042288, 0.41937772949721147, 0.36...
# 39         0.029225  [0.6915813516330773, 0.5963801760227191, 0.490...
# 40         0.082676  [0.3568050816993144, 0.2032611132761762, 0.424...
# 41         0.032173  [0.2411917234843051, 0.04997777990313389, 0.07...
# 42         0.058276  [0.2571515045672813, 0.40375886225503527, 0.16...
# 43         0.056459  [0.14970692538948027, 0.10097902421799135, 0.3...
# 44         0.079234  [0.32302503657383475, 0.17139125130514807, 0.1...
# 45         0.098325  [0.3041453130203139, 0.35691077760132445, 0.61...
# 46         0.081608  [0.2955847803073119, 0.27755436758366414, -0.1...
# 47         0.038794  [0.31956772797192134, 0.5182546098166189, 0.49...
# 48         0.055223  [0.10038214933412867, 0.27398534533494817, 0.1...
# 49         0.060012  [0.20264417732518197, 0.0546450685612571, 0.29...

# %%
def plot_all_metrics(aggregated_results, dataset_name):
    plt.rcParams['font.family'] = 'Arial'
    plt.rcParams['font.size'] = 12
    
    result_dir = f'gradient_similarity/{dataset_name}/plots'
    if not os.path.exists(result_dir):
        os.makedirs(result_dir)
    
    methods = aggregated_results['method'].unique()
    p_vals = sorted(aggregated_results['p'].unique())
    
    num_methods = len(methods)
    fig, axs = plt.subplots(num_methods, 3, figsize=(24, 4*num_methods))
    
    metrics = ['M3_task', 'M1_grad_sim', 'M2_grad_sim']
    titles = [f'M3 Task {task_no} Average Accuracy', 'M1 Gradient Similarity', 'M2 Gradient Similarity']
    
    for method_index, method in enumerate(methods):
        method_data = aggregated_results[aggregated_results['method'] == method]
        
        for col, (metric, title) in enumerate(zip(metrics, titles)):
            if num_methods == 1:
                ax = axs[col]
            else:
                ax = axs[method_index, col]
            
            avg_values = [method_data[method_data['p'] == p][f'{metric}_avg'].values[0] for p in p_vals]
            std_values = [method_data[method_data['p'] == p][f'{metric}_std'].values[0] for p in p_vals]
            
            ax.plot(p_vals, avg_values, marker='o', label=method)
            ax.fill_between(p_vals, 
                            np.array(avg_values) - np.array(std_values), 
                            np.array(avg_values) + np.array(std_values), 
                            alpha=0.2)
            
            ax.set_xscale('log')
            ax.set_title(f'{title} for {method}', fontsize=10)
            ax.legend(fontsize=8)
            
            ax.set_xticks(p_vals)
            ax.set_xticklabels([f'{p:.3f}' for p in p_vals], rotation=45, ha='right')
            
            if method_index == num_methods - 1:  # Last row
                ax.set_xlabel('p values')
            
            if col == 0:  # First column
                ax.set_ylabel(title)
    
    # plt.tight_layout()
    # dataset_name = params['exp_name'][0]
    # plt.savefig(f'{result_dir}/{OUTPUT_DIR}/{dataset_name}/all_metrics_average.png')
    # plt.show()

plot_all_metrics(aggregated_results, 'dataset_name')

# %%
def plot_all_metrics_normalize_axis(aggregated_results, dataset_name):
    plt.rcParams['font.family'] = 'Arial'
    plt.rcParams['font.size'] = 12
    
    result_dir = f'gradient_similarity/{dataset_name}/plots'
    if not os.path.exists(result_dir):
        os.makedirs(result_dir)
    
    methods = aggregated_results['method'].unique()
    p_vals = sorted(aggregated_results['p'].unique())
    
    num_methods = len(methods)
    fig, axs = plt.subplots(num_methods, 3, figsize=(24, 4*num_methods))
    
    metrics = ['M3_task', 'M1_grad_sim', 'M2_grad_sim']
    titles = [f'M3 Task {task_no} Average', 'M1 Gradient Similarity', 'M2 Gradient Similarity']
    
    # Find global min and max for each metric, including std
    y_limits = {}
    for metric in metrics:
        min_val = (aggregated_results[f'{metric}_avg'] - aggregated_results[f'{metric}_std']).min()
        max_val = (aggregated_results[f'{metric}_avg'] + aggregated_results[f'{metric}_std']).max()
        y_range = max_val - min_val
        y_limits[metric] = (min_val - 0.1 * y_range, max_val + 0.1 * y_range)
    
    for method_index, method in enumerate(methods):
        method_data = aggregated_results[aggregated_results['method'] == method]
        
        for col, (metric, title) in enumerate(zip(metrics, titles)):
            if num_methods == 1:
                ax = axs[col]
            else:
                ax = axs[method_index, col]
            
            avg_values = [method_data[method_data['p'] == p][f'{metric}_avg'].values[0] for p in p_vals]
            std_values = [method_data[method_data['p'] == p][f'{metric}_std'].values[0] for p in p_vals]
            
            ax.plot(p_vals, avg_values, marker='o', label=method)
            ax.fill_between(p_vals, 
                            np.array(avg_values) - np.array(std_values), 
                            np.array(avg_values) + np.array(std_values), 
                            alpha=0.2)
            
            ax.set_xscale('log')
            ax.set_title(f'{title} for {method}', fontsize=10)
            ax.legend(fontsize=8)
            
            ax.set_xticks(p_vals)
            ax.set_xticklabels([f'{p:.3f}' for p in p_vals], rotation=45, ha='right')
            
            # Set y-axis limits to be the same for all methods within each metric
            ax.set_ylim(y_limits[metric])
            
            if method_index == num_methods - 1:  # Last row
                ax.set_xlabel('p values')
            
            if col == 0:  # First column
                ax.set_ylabel(title)
    
    # plt.tight_layout()
    # plt.savefig(f'{result_dir}/{OUTPUT_DIR}/{params['exp_name'][0]}/all_metrics_average.png')
    # plt.show()

plot_all_metrics_normalize_axis(aggregated_results, 'dataset_name')

# %%
# def plot_all_metrics(aggregated_results, dataset_name):
#     plt.rcParams['font.family'] = 'Arial'
#     plt.rcParams['font.size'] = 8
    
#     result_dir = f'gradient_similarity/{dataset_name}/plots'
#     if not os.path.exists(result_dir):
#         os.makedirs(result_dir)
    
#     methods = aggregated_results['method'].unique()
#     p_vals = sorted(aggregated_results['p'].unique())
    
#     num_methods = len(methods)
#     fig, axs = plt.subplots(num_methods, 3, figsize=(24, 4*num_methods))
    
#     metrics = ['M3_task', 'M1_grad_sim', 'M2_grad_sim']
#     titles = [f'M3 Task {task_no} Accuracy', 'M1 Gradient Similarity', 'M2 Gradient Similarity']
    
#     for method_index, method in enumerate(methods):
#         method_data = aggregated_results[aggregated_results['method'] == method]
        
#         for col, (metric, title) in enumerate(zip(metrics, titles)):
#             if num_methods == 1:
#                 ax = axs[col]
#             else:
#                 ax = axs[method_index, col]
            
#             # Get the number of samples
#             num_samples = len(method_data[method_data['p'] == p_vals[0]][f'{metric}_array'].values[0])
            
#             for sample_index in range(num_samples):
#                 sample_values = [method_data[method_data['p'] == p][f'{metric}_array'].values[0][sample_index] for p in p_vals]
#                 ax.plot(p_vals, sample_values, alpha=0.3, linewidth=1)
            
#             # Calculate and plot the mean
#             mean_values = [np.mean(method_data[method_data['p'] == p][f'{metric}_array'].values[0]) for p in p_vals]
#             ax.plot(p_vals, mean_values, color='red', linewidth=2, label='Mean')
            
#             ax.set_xscale('log')
#             ax.set_title(f'{title} for {method}', fontsize=10)
#             ax.legend(fontsize=8)
            
#             ax.set_xticks(p_vals)
#             ax.set_xticklabels([f'{p:.3f}' for p in p_vals], rotation=45, ha='right')
            
#             if method_index == num_methods - 1:  # Last row
#                 ax.set_xlabel('p values')
            
#             if col == 0:  # First column
#                 ax.set_ylabel(title)
    
#     # plt.tight_layout()
#     # plt.savefig(f'{result_dir}/{OUTPUT_DIR}/{params['exp_name'][0]}/all_metrics_methods.png')
#     # plt.show()

# plot_all_metrics(aggregated_results, 'dataset_name')

# %%
aggregated_results
# Out:
#         p                  method  samples  M3_task_avg  M3_task_std  \
# 0   0.900  RandomMemorySetManager        5       0.7676     0.009468
# 1   0.900  KMeansMemorySetManager        5       0.7484     0.015013
# 2   0.900  LambdaMemorySetManager        5       0.7627     0.004410
# 3   0.900           iCaRL (icarl)        5       0.7605     0.006603
# 4   0.900          iCaRL (replay)        5       0.7486     0.008729
# 5   0.500  RandomMemorySetManager        5       0.6922     0.023024
# 6   0.500  KMeansMemorySetManager        5       0.7166     0.011248
# 7   0.500  LambdaMemorySetManager        5       0.7318     0.007114
# 8   0.500           iCaRL (icarl)        5       0.7147     0.005549
# 9   0.500          iCaRL (replay)        5       0.7509     0.008406
# 10  0.200  RandomMemorySetManager        5       0.5066     0.024279
# 11  0.200  KMeansMemorySetManager        5       0.5309     0.019199
# 12  0.200  LambdaMemorySetManager        5       0.5479     0.025154
# 13  0.200           iCaRL (icarl)        5       0.5713     0.012129
# 14  0.200          iCaRL (replay)        5       0.5941     0.009714
# 15  0.005  RandomMemorySetManager        5       0.0062     0.001246
# 16  0.005  KMeansMemorySetManager        5       0.0146     0.001977
# 17  0.005  LambdaMemorySetManager        5       0.0048     0.001604
# 18  0.005           iCaRL (icarl)        5       0.0086     0.001615
# 19  0.005          iCaRL (replay)        5       0.0119     0.001774
# 20  0.020  RandomMemorySetManager        5       0.0832     0.008864
# 21  0.020  KMeansMemorySetManager        5       0.0927     0.007337
# 22  0.020  LambdaMemorySetManager        5       0.1046     0.016319
# 23  0.020           iCaRL (icarl)        5       0.1015     0.020086
# 24  0.020          iCaRL (replay)        5       0.1042     0.011651
# 25  0.001  RandomMemorySetManager        5       0.0003     0.000110
# 26  0.001  KMeansMemorySetManager        5       0.0001     0.000089
# 27  0.001  LambdaMemorySetManager        5       0.0002     0.000110
# 28  0.001           iCaRL (icarl)        5       0.0008     0.000363
# 29  0.001          iCaRL (replay)        5       0.0007     0.000303
# 30  0.100  RandomMemorySetManager        5       0.3858     0.016084
# 31  0.100  KMeansMemorySetManager        5       0.3753     0.013048
# 32  0.100  LambdaMemorySetManager        5       0.3283     0.020484
# 33  0.100           iCaRL (icarl)        5       0.4043     0.020524
# 34  0.100          iCaRL (replay)        5       0.4784     0.015063
# 35  0.050  RandomMemorySetManager        5       0.2167     0.013922
# 36  0.050  KMeansMemorySetManager        5       0.2291     0.023831
# 37  0.050  LambdaMemorySetManager        5       0.1947     0.021938
# 38  0.050           iCaRL (icarl)        5       0.2546     0.028602
# 39  0.050          iCaRL (replay)        5       0.3003     0.010884
# 40  0.002  RandomMemorySetManager        5       0.0017     0.000610
# 41  0.002  KMeansMemorySetManager        5       0.0019     0.000654
# 42  0.002  LambdaMemorySetManager        5       0.0005     0.000346
# 43  0.002           iCaRL (icarl)        5       0.0015     0.000490
# 44  0.002          iCaRL (replay)        5       0.0021     0.000385
# 45  0.010  RandomMemorySetManager        5       0.0184     0.001670
# 46  0.010  KMeansMemorySetManager        5       0.0419     0.005287
# 47  0.010  LambdaMemorySetManager        5       0.0357     0.008083
# 48  0.010           iCaRL (icarl)        5       0.0366     0.006052
# 49  0.010          iCaRL (replay)        5       0.0315     0.003314
#
#                               M3_task_array  M1_grad_sim_avg  M1_grad_sim_std  \
# 0   [0.7665, 0.7475, 0.7465, 0.8045, 0.773]         0.993427         0.001402
# 1     [0.714, 0.777, 0.7025, 0.7645, 0.784]         0.985912         0.001956
# 2    [0.759, 0.7755, 0.747, 0.7705, 0.7615]         0.999067         0.000224
# 3      [0.785, 0.7635, 0.749, 0.742, 0.763]         0.991804         0.001768
# 4     [0.769, 0.7485, 0.762, 0.751, 0.7125]         0.990260         0.002338
# 5   [0.6615, 0.6415, 0.702, 0.7875, 0.6685]         0.952494         0.006600
# 6     [0.751, 0.733, 0.7065, 0.716, 0.6765]         0.888091         0.014526
# 7     [0.758, 0.7245, 0.726, 0.7395, 0.711]         0.987240         0.002102
# 8      [0.723, 0.691, 0.7155, 0.726, 0.718]         0.955809         0.008740
# 9    [0.7795, 0.747, 0.7345, 0.7645, 0.729]         0.947417         0.009828
# 10  [0.5685, 0.443, 0.4445, 0.5165, 0.5605]         0.842916         0.021410
# 11   [0.487, 0.565, 0.4705, 0.5685, 0.5635]         0.713494         0.045680
# 12     [0.5295, 0.452, 0.616, 0.554, 0.588]         0.960098         0.006479
# 13      [0.5705, 0.53, 0.565, 0.615, 0.576]         0.851617         0.018096
# 14     [0.5835, 0.574, 0.592, 0.636, 0.585]         0.766663         0.042146
# 15   [0.01, 0.0065, 0.0015, 0.0055, 0.0075]         0.269520         0.088765
# 16     [0.01, 0.0155, 0.014, 0.0225, 0.011]         0.269962         0.116323
# 17    [0.0035, 0.005, 0.003, 0.001, 0.0115]         0.600258         0.038675
# 18  [0.006, 0.0125, 0.0055, 0.0055, 0.0135]         0.344435         0.027829
# 19   [0.009, 0.0185, 0.009, 0.0145, 0.0085]         0.283207         0.046414
# 20    [0.0865, 0.1185, 0.079, 0.059, 0.073]         0.496168         0.039798
# 21     [0.067, 0.093, 0.106, 0.1135, 0.084]         0.411722         0.098906
# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.patches import Ellipse
import matplotlib.transforms as transforms

def confidence_ellipse(x, y, ax, n_std=3.0, facecolor='none', **kwargs):
    if x.size != y.size:
        raise ValueError("x and y must be the same size")

    cov = np.cov(x, y)
    pearson = cov[0, 1]/np.sqrt(cov[0, 0] * cov[1, 1])

    ell_radius_x = np.sqrt(1 + pearson)
    ell_radius_y = np.sqrt(1 - pearson)
    ellipse = Ellipse((0, 0), width=ell_radius_x * 2, height=ell_radius_y * 2,
                      facecolor=facecolor, **kwargs)

    scale_x = np.sqrt(cov[0, 0]) * n_std
    mean_x = np.mean(x)

    scale_y = np.sqrt(cov[1, 1]) * n_std
    mean_y = np.mean(y)

    transf = transforms.Affine2D() \
        .rotate_deg(45) \
        .scale(scale_x, scale_y) \
        .translate(mean_x, mean_y)

    ellipse.set_transform(transf + ax.transData)
    return ax.add_patch(ellipse)

def adapted_batch_scatterplot_grad_dist(aggregated_results, dataset_name, plot_ellipse=False):
    plt.rcParams['font.family'] = 'Arial'
    plt.rcParams['font.size'] = 20
    
    result_dir = f'gradient_similarity/{dataset_name}/plots'
    if not os.path.exists(result_dir):
        os.makedirs(result_dir)
    
    plt.figure(figsize=(20, 10))
    ax = plt.gca()
    
    methods = aggregated_results['method'].unique()
    p_vals = sorted(aggregated_results['p'].unique())
    
    for p in p_vals:
        accs = []
        grad_pts = []
        grad_vars = []
        
        for method in methods:
            method_data = aggregated_results[(aggregated_results['method'] == method) & 
                                             (aggregated_results['p'] == p)]
            
            accs.append(method_data['M3_task_avg'].values[0])
            grad_pts.append(method_data['M1_grad_sim_avg'].values[0])
            grad_vars.append(method_data['M1_grad_sim_std'].values[0])
        
        accs = np.array(accs)
        grad_pts = np.array(grad_pts)
        grad_vars = np.array(grad_vars)
        
        obj = ax.scatter(accs, grad_pts, label=f'p = {p:.3f}')
        if plot_ellipse:
            confidence_ellipse(accs, grad_pts, ax, n_std=1.0, edgecolor=obj.get_edgecolor())
        else:
            plt.errorbar(accs, grad_pts, yerr=grad_vars, ls='none')

    plt.xlim(0, 1)
    plt.ylim(0, 1.1)
    plt.title(f'Gradient Similarity vs Downstream Accuracy for Memory Selection Methods')
    plt.ylabel('Gradient Similarity (M1)')
    plt.xlabel('Downstream Accuracy (M3)')
    plt.legend(loc='lower left')
    
    if plot_ellipse:
        plt.savefig(f'{result_dir}/batch_scatterplot_ellipse.png')
    else:
        plt.savefig(f'{result_dir}/batch_scatterplot.png')
    plt.show()

# Usage

# %%
adapted_batch_scatterplot_grad_dist(aggregated_results, 'dataset_name', plot_ellipse=False)

# %%
def adapted_batch_scatterplot_grad_dist(aggregated_results, dataset_name, plot_ellipse=False):
    plt.rcParams['font.family'] = 'Arial'
    plt.rcParams['font.size'] = 10  # Reduced font size for better fit
    
    result_dir = f'gradient_similarity/{dataset_name}/plots'
    if not os.path.exists(result_dir):
        os.makedirs(result_dir)
    
    methods = aggregated_results['method'].unique()
    p_vals = sorted(aggregated_results['p'].unique())
    
    num_methods = len(methods)
    
    # Create subplots with appropriate figure size
    fig, axs = plt.subplots(num_methods, 2, figsize=(20, 6*num_methods)) if num_methods > 1 else plt.subplots(1, 2, figsize=(20, 6))
    
    for method_index, method in enumerate(methods):
        for col, metric in enumerate(['M1', 'M2']):
            # Adjust indexing based on the number of methods
            if num_methods == 1:
                ax = axs[col]  # axs is 1D when there's only one method
            else:
                ax = axs[method_index, col]  # axs is 2D otherwise
            
            for p in p_vals:
                method_data = aggregated_results[(aggregated_results['method'] == method) & 
                                                 (aggregated_results['p'] == p)]
                
                accs = method_data['M3_task_avg'].values
                grad_pts = method_data[f'{metric}_grad_sim_avg'].values
                grad_vars = method_data[f'{metric}_grad_sim_std'].values
                
                obj = ax.scatter(accs, grad_pts, label=f'p = {p:.3f}')
                if plot_ellipse:
                    confidence_ellipse(accs, grad_pts, ax, n_std=1.0, edgecolor=obj.get_edgecolor())
                else:
                    ax.errorbar(accs, grad_pts, yerr=grad_vars, ls='none')

            ax.set_xlim(0, 1)
            ax.set_ylim(0, 1.1)
            ax.set_title(f'{method}: {metric} Gradient Similarity vs Downstream Accuracy')
            ax.set_ylabel(f'{metric} Gradient Similarity')
            ax.set_xlabel('Downstream Accuracy (M3)')
            
            if method_index == 0 and col == 1:  # Only add legend to the top-right subplot
                ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)

    plt.tight_layout()
    
    # Add the main title
    fig.suptitle('Gradient Similarity vs Downstream Accuracy for Memory Selection Methods', 
                 fontsize=16, y=1.02)
    
    # Adjust the figure size to accommodate the title
    fig.subplots_adjust(top=0.95)
    
    # Save the figure
    if plot_ellipse:
        plt.savefig(f'{result_dir}/batch_scatterplot_ellipse_all_methods.png', bbox_inches='tight', dpi=300)
    else:
        plt.savefig(f'{result_dir}/batch_scatterplot_all_methods.png', bbox_inches='tight', dpi=300)
    
    plt.show()

# Usage
adapted_batch_scatterplot_grad_dist(aggregated_results, 'dataset_name', plot_ellipse=False)

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.patches import Ellipse
import matplotlib.transforms as transforms
from matplotlib.lines import Line2D

def confidence_ellipse(x, y, ax, n_std=3.0, facecolor='none', **kwargs):
    if x.size != y.size:
        raise ValueError("x and y must be the same size")

    cov = np.cov(x, y)
    pearson = cov[0, 1]/np.sqrt(cov[0, 0] * cov[1, 1])

    ell_radius_x = np.sqrt(1 + pearson)
    ell_radius_y = np.sqrt(1 - pearson)
    ellipse = Ellipse((0, 0), width=ell_radius_x * 2, height=ell_radius_y * 2,
                      facecolor=facecolor, **kwargs)

    scale_x = np.sqrt(cov[0, 0]) * n_std
    mean_x = np.mean(x)

    scale_y = np.sqrt(cov[1, 1]) * n_std
    mean_y = np.mean(y)

    transf = transforms.Affine2D() \
        .rotate_deg(45) \
        .scale(scale_x, scale_y) \
        .translate(mean_x, mean_y)

    ellipse.set_transform(transf + ax.transData)
    return ax.add_patch(ellipse)


def adapted_batch_scatterplot_grad_dist(aggregated_results, dataset_name, plot_ellipse=False):
    plt.rcParams['font.family'] = 'Arial'
    plt.rcParams['font.size'] = 12
    
    result_dir = f'gradient_similarity/{dataset_name}/plots'
    if not os.path.exists(result_dir):
        os.makedirs(result_dir)
    
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 10))
    
    methods = aggregated_results['method'].unique()
    p_vals = sorted(aggregated_results['p'].unique())
    
    # Define markers and colors
    markers = ['o', 's', '^', 'D', 'v', '<', '>', 'p', '*', 'h', 'H', '+', 'x', 'd']
    colors = plt.cm.get_cmap('tab10')(np.linspace(0, 1, len(p_vals)))
    
    for ax, metric in zip([ax1, ax2], ['M1', 'M2']):
        for i, method in enumerate(methods):
            for j, p in enumerate(p_vals):
                method_data = aggregated_results[(aggregated_results['method'] == method) & 
                                                 (aggregated_results['p'] == p)]
                
                accs = method_data['M3_task_avg'].values
                grad_pts = method_data[f'{metric}_grad_sim_avg'].values
                grad_vars = method_data[f'{metric}_grad_sim_std'].values
                
                obj = ax.scatter(accs, grad_pts, marker=markers[i % len(markers)], c=[colors[j]], 
                                 s=50)
                if plot_ellipse:
                    confidence_ellipse(accs, grad_pts, ax, n_std=1.0, edgecolor=obj.get_edgecolor())
                else:
                    ax.errorbar(accs, grad_pts, yerr=grad_vars, ls='none', c=colors[j], alpha=0.5)

        ax.set_xlim(0, 1)
        ax.set_ylim(0, 1.1)
        ax.set_title(f'{metric} Gradient Similarity vs Downstream Accuracy')
        ax.set_ylabel(f'{metric} Gradient Similarity')
        ax.set_xlabel('Downstream Accuracy (M3)')
    
    # Create separate legends for methods and p-values
    method_legend_elements = [Line2D([0], [0], marker=markers[i % len(markers)], color='w', 
                              markerfacecolor='gray', markersize=10, label=method)
                              for i, method in enumerate(methods)]
    
    p_value_legend_elements = [Line2D([0], [0], marker='o', color='w', 
                               markerfacecolor=colors[i], markersize=10, 
                               label=f'p = {p:.3f}')
                               for i, p in enumerate(p_vals)]
    
    # Add legends to the figure
    fig.legend(handles=method_legend_elements, loc='center left', 
               bbox_to_anchor=(1, 0.7), title="Methods")
    fig.legend(handles=p_value_legend_elements, loc='center left', 
               bbox_to_anchor=(1, 0.3), title="P-values")
    
    plt.tight_layout()
    
    # Add the main title
    fig.suptitle('Gradient Similarity vs Downstream Accuracy for Memory Selection Methods', 
                 fontsize=16, y=1.02)
    
    # Adjust the figure size to accommodate the title and legends
    fig.subplots_adjust(top=0.9, right=0.85)
    
    if plot_ellipse:
        plt.savefig(f'{result_dir}/batch_scatterplot_ellipse_combined.png', bbox_inches='tight', dpi=300)
    else:
        plt.savefig(f'{result_dir}/batch_scatterplot_combined.png', bbox_inches='tight', dpi=300)
    plt.show()

# Usage
adapted_batch_scatterplot_grad_dist(aggregated_results, 'dataset_name', plot_ellipse=False)
# Out:
# /var/folders/9m/3sbbk6pn0ggcr_ynzqxr4ll00000gn/T/ipykernel_6694/960113734.py:49: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colors = plt.cm.get_cmap('tab10')(np.linspace(0, 1, len(p_vals)))

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.patches import Ellipse
import matplotlib.transforms as transforms
from matplotlib.lines import Line2D
from collections import defaultdict

def confidence_ellipse(x, y, ax, n_std=3.0, facecolor='none', **kwargs):
    if x.size != y.size:
        raise ValueError("x and y must be the same size")

    cov = np.cov(x, y)
    pearson = cov[0, 1]/np.sqrt(cov[0, 0] * cov[1, 1])

    ell_radius_x = np.sqrt(1 + pearson)
    ell_radius_y = np.sqrt(1 - pearson)
    ellipse = Ellipse((0, 0), width=ell_radius_x * 2, height=ell_radius_y * 2,
                      facecolor=facecolor, **kwargs)

    scale_x = np.sqrt(cov[0, 0]) * n_std
    mean_x = np.mean(x)

    scale_y = np.sqrt(cov[1, 1]) * n_std
    mean_y = np.mean(y)

    transf = transforms.Affine2D() \
        .rotate_deg(45) \
        .scale(scale_x, scale_y) \
        .translate(mean_x, mean_y)

    ellipse.set_transform(transf + ax.transData)
    return ax.add_patch(ellipse)

def get_unique_markers(methods):
    marker_dict = {}
    initial_count = defaultdict(int)
    
    for method in methods:
        initial = method[0].upper()
        count = initial_count[initial]
        initial_count[initial] += 1
        
        if count == 0:
            marker_dict[method] = initial
        else:
            marker_dict[method] = f'{initial}{count}'
    
    return marker_dict

def adapted_batch_scatterplot_grad_dist(aggregated_results, dataset_name, plot_ellipse=False):
    plt.rcParams['font.family'] = 'Arial'
    plt.rcParams['font.size'] = 12
    
    result_dir = f'gradient_similarity/{dataset_name}/plots'
    if not os.path.exists(result_dir):
        os.makedirs(result_dir)
    
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 10))
    
    methods = aggregated_results['method'].unique()
    p_vals = sorted(aggregated_results['p'].unique())
    
    # Define markers and colors
    marker_dict = get_unique_markers(methods)
    colors = plt.cm.get_cmap('tab10')(np.linspace(0, 1, len(p_vals)))
    
    for ax, metric in zip([ax1, ax2], ['M1', 'M2']):
        for method in methods:
            for j, p in enumerate(p_vals):
                method_data = aggregated_results[(aggregated_results['method'] == method) & 
                                                 (aggregated_results['p'] == p)]
                
                accs = method_data['M3_task_avg'].values
                grad_pts = method_data[f'{metric}_grad_sim_avg'].values
                grad_vars = method_data[f'{metric}_grad_sim_std'].values
                
                obj = ax.scatter(accs, grad_pts, marker=f'${marker_dict[method]}$', c=[colors[j]], 
                                 s=100)
                if plot_ellipse:
                    confidence_ellipse(accs, grad_pts, ax, n_std=1.0, edgecolor=obj.get_edgecolor())
                else:
                    ax.errorbar(accs, grad_pts, yerr=grad_vars, ls='none', c=colors[j], alpha=0.5)

        ax.set_xlim(0, 1)
        ax.set_ylim(0, 1.1)
        ax.set_title(f'{metric} Gradient Similarity vs Downstream Accuracy')
        ax.set_ylabel(f'{metric} Gradient Similarity')
        ax.set_xlabel('Downstream Accuracy (M3)')
    
    # Create separate legends for methods and p-values
    method_legend_elements = [Line2D([0], [0], marker=f'${marker_dict[method]}$', color='w', 
                              markerfacecolor='gray', markersize=15, label=method)
                              for method in methods]
    
    p_value_legend_elements = [Line2D([0], [0], marker='o', color='w', 
                               markerfacecolor=colors[i], markersize=10, 
                               label=f'p = {p:.3f}')
                               for i, p in enumerate(p_vals)]
    
    # Add legends to the figure
    fig.legend(handles=method_legend_elements, loc='center left', 
               bbox_to_anchor=(1, 0.7), title="Methods")
    fig.legend(handles=p_value_legend_elements, loc='center left', 
               bbox_to_anchor=(1, 0.3), title="P-values")
    
    plt.tight_layout()
    
    # Add the main title
    fig.suptitle('Gradient Similarity vs Downstream Accuracy for Memory Selection Methods', 
                 fontsize=16, y=1.02)
    
    # Adjust the figure size to accommodate the title and legends
    fig.subplots_adjust(top=0.9, right=0.85)
    
    if plot_ellipse:
        plt.savefig(f'{result_dir}/batch_scatterplot_ellipse_combined.png', bbox_inches='tight', dpi=300)
    else:
        plt.savefig(f'{result_dir}/batch_scatterplot_combined.png', bbox_inches='tight', dpi=300)
    plt.show()

# Usage
adapted_batch_scatterplot_grad_dist(aggregated_results, 'dataset_name', plot_ellipse=False)
# Out:
# /var/folders/9m/3sbbk6pn0ggcr_ynzqxr4ll00000gn/T/ipykernel_6694/2430982485.py:65: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colors = plt.cm.get_cmap('tab10')(np.linspace(0, 1, len(p_vals)))

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.patches import Ellipse
import matplotlib.transforms as transforms
from matplotlib.lines import Line2D

def confidence_ellipse(x, y, ax, n_std=3.0, facecolor='none', **kwargs):
    if x.size != y.size:
        raise ValueError("x and y must be the same size")

    cov = np.cov(x, y)
    pearson = cov[0, 1]/np.sqrt(cov[0, 0] * cov[1, 1])

    ell_radius_x = np.sqrt(1 + pearson)
    ell_radius_y = np.sqrt(1 - pearson)
    ellipse = Ellipse((0, 0), width=ell_radius_x * 2, height=ell_radius_y * 2,
                      facecolor=facecolor, **kwargs)

    scale_x = np.sqrt(cov[0, 0]) * n_std
    mean_x = np.mean(x)

    scale_y = np.sqrt(cov[1, 1]) * n_std
    mean_y = np.mean(y)

    transf = transforms.Affine2D() \
        .rotate_deg(45) \
        .scale(scale_x, scale_y) \
        .translate(mean_x, mean_y)

    ellipse.set_transform(transf + ax.transData)
    return ax.add_patch(ellipse)

def adapted_batch_scatterplot_grad_dist(aggregated_results, dataset_name, plot_ellipse=False):
    plt.rcParams['font.family'] = 'Arial'
    plt.rcParams['font.size'] = 12
    
    result_dir = f'gradient_similarity/{dataset_name}/plots'
    if not os.path.exists(result_dir):
        os.makedirs(result_dir)
    
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 10))
    
    methods = aggregated_results['method'].unique()
    p_vals = sorted(aggregated_results['p'].unique())
    
    # Define markers and colors
    markers = ['o', 's', '^', 'D', 'v', '<', '>', 'p', '*', 'h', 'H', '+', 'x', 'd']
    colors = plt.cm.get_cmap('tab10')(np.linspace(0, 1, len(p_vals)))
    
    for ax, metric in zip([ax1, ax2], ['M1', 'M2']):
        for i, method in enumerate(methods):
            for j, p in enumerate(p_vals):
                method_data = aggregated_results[(aggregated_results['method'] == method) & 
                                                 (aggregated_results['p'] == p)]
                
                accs = method_data['M3_task_avg'].values
                grad_pts = method_data[f'{metric}_grad_sim_avg'].values
                grad_vars = method_data[f'{metric}_grad_sim_std'].values
                
                obj = ax.scatter(accs, grad_pts, marker=markers[i % len(markers)], c=[colors[j]], 
                                 s=50)
                if plot_ellipse:
                    confidence_ellipse(accs, grad_pts, ax, n_std=1.0, edgecolor=obj.get_edgecolor())
                else:
                    ax.errorbar(accs, grad_pts, yerr=grad_vars, ls='none', c=colors[j], alpha=0.5)

        ax.set_xscale('log')  # Set x-axis to logarithmic scale
        ax.set_xlim(0.01, 1)  # Adjust lower limit to avoid log(0)
        ax.set_ylim(0, 1.1)
        ax.set_title(f'{metric} Gradient Similarity vs Downstream Accuracy')
        ax.set_ylabel(f'{metric} Gradient Similarity')
        ax.set_xlabel('Downstream Accuracy (M3) - Log Scale')
        
        # Add minor ticks
        ax.xaxis.set_minor_locator(plt.LogLocator(base=10, subs=np.arange(1.0, 10.0) * 0.1, numticks=10))
        ax.xaxis.set_minor_formatter(plt.NullFormatter())
        
        # Customize x-axis ticks
        ax.set_xticks([0.01, 0.1, 1])
        ax.set_xticklabels(['0.01', '0.1', '1'])

    # Create separate legends for methods and p-values
    method_legend_elements = [Line2D([0], [0], marker=markers[i % len(markers)], color='w', 
                              markerfacecolor='gray', markersize=10, label=method)
                              for i, method in enumerate(methods)]
    
    p_value_legend_elements = [Line2D([0], [0], marker='o', color='w', 
                               markerfacecolor=colors[i], markersize=10, 
                               label=f'p = {p:.3f}')
                               for i, p in enumerate(p_vals)]
    
    # Add legends to the figure
    fig.legend(handles=method_legend_elements, loc='center left', 
               bbox_to_anchor=(1, 0.7), title="Methods")
    fig.legend(handles=p_value_legend_elements, loc='center left', 
               bbox_to_anchor=(1, 0.3), title="P-values")
    
    plt.tight_layout()
    
    # Add the main title
    fig.suptitle('Gradient Similarity vs Downstream Accuracy for Memory Selection Methods', 
                 fontsize=16, y=1.02)
    
    # Adjust the figure size to accommodate the title and legends
    fig.subplots_adjust(top=0.9, right=0.85)
    
    if plot_ellipse:
        plt.savefig(f'{result_dir}/batch_scatterplot_ellipse_combined_log.png', bbox_inches='tight', dpi=300)
    else:
        plt.savefig(f'{result_dir}/batch_scatterplot_combined_log.png', bbox_inches='tight', dpi=300)
    plt.show()

# Usage
adapted_batch_scatterplot_grad_dist(aggregated_results, 'dataset_name', plot_ellipse=False)
# Out:
# /var/folders/9m/3sbbk6pn0ggcr_ynzqxr4ll00000gn/T/ipykernel_6694/4002355681.py:48: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colors = plt.cm.get_cmap('tab10')(np.linspace(0, 1, len(p_vals)))

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.patches import Ellipse
import matplotlib.transforms as transforms
from matplotlib.lines import Line2D
import os

def confidence_ellipse(x, y, ax, n_std=3.0, facecolor='none', **kwargs):
    if x.size != y.size:
        raise ValueError("x and y must be the same size")

    cov = np.cov(x, y)
    pearson = cov[0, 1]/np.sqrt(cov[0, 0] * cov[1, 1])

    ell_radius_x = np.sqrt(1 + pearson)
    ell_radius_y = np.sqrt(1 - pearson)
    ellipse = Ellipse((0, 0), width=ell_radius_x * 2, height=ell_radius_y * 2,
                      facecolor=facecolor, **kwargs)

    scale_x = np.sqrt(cov[0, 0]) * n_std
    mean_x = np.mean(x)

    scale_y = np.sqrt(cov[1, 1]) * n_std
    mean_y = np.mean(y)

    transf = transforms.Affine2D() \
        .rotate_deg(45) \
        .scale(scale_x, scale_y) \
        .translate(mean_x, mean_y)

    ellipse.set_transform(transf + ax.transData)
    return ax.add_patch(ellipse)

def create_scatterplot(ax, aggregated_results, methods, p_vals, markers, colors, metric, plot_ellipse):
    for i, method in enumerate(methods):
        for j, p in enumerate(p_vals):
            method_data = aggregated_results[(aggregated_results['method'] == method) & 
                                             (aggregated_results['p'] == p)]
            
            accs = method_data['M3_task_avg'].values
            accs_std = method_data['M3_task_std'].values
            grad_pts = method_data[f'{metric}_grad_sim_avg'].values
            grad_vars = method_data[f'{metric}_grad_sim_std'].values
            
            obj = ax.scatter(accs, grad_pts, marker=markers[i % len(markers)], c=[colors[j]], 
                             s=50, zorder=3)
            if plot_ellipse:
                confidence_ellipse(accs, grad_pts, ax, n_std=1.0, edgecolor=obj.get_edgecolor())
            else:
                ax.errorbar(accs, grad_pts, xerr=accs_std, yerr=grad_vars, 
                            fmt='none', ecolor=colors[j], alpha=0.5, zorder=2)

    ax.set_ylim(0, 1.1)
    ax.set_title(f'{metric} Gradient Similarity vs Downstream Accuracy')
    ax.set_ylabel(f'{metric} Gradient Similarity')
    ax.set_xlabel('Downstream Accuracy (M3)')

def adapted_batch_scatterplot_grad_dist(aggregated_results, dataset_name, exp_name, plot_ellipse=False):
    plt.rcParams['font.family'] = 'Arial'
    plt.rcParams['font.size'] = 12
    
    result_dir = f'gradient_similarity/{dataset_name}/plots'
    if not os.path.exists(result_dir):
        os.makedirs(result_dir)
    
    methods = aggregated_results['method'].unique()
    p_vals = sorted(aggregated_results['p'].unique())
    
    markers = ['o', 's', '^', 'D', 'v', '<', '>', 'p', '*', 'h', 'H', '+', 'x', 'd']
    colors = plt.cm.get_cmap('tab10')(np.linspace(0, 1, len(p_vals)))
    
    for scale in ['log', 'linear']:
        fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 10))
        
        for ax, metric in zip([ax1, ax2], ['M1', 'M2']):
            create_scatterplot(ax, aggregated_results, methods, p_vals, markers, colors, metric, plot_ellipse)
            
            if scale == 'log':
                ax.set_xscale('log')
                ax.set_xlim(0.01, 1)
                ax.xaxis.set_minor_locator(plt.LogLocator(base=10, subs=np.arange(1.0, 10.0) * 0.1, numticks=10))
                ax.xaxis.set_minor_formatter(plt.NullFormatter())
                ax.set_xticks([0.01, 0.1, 1])
                ax.set_xticklabels(['0.01', '0.1', '1'])
                ax.set_xlabel('Downstream Accuracy (M3) - Log Scale')
            else:
                ax.set_xlim(0, 1)
                ax.set_xlabel('Downstream Accuracy (M3)')

        method_legend_elements = [Line2D([0], [0], marker=markers[i % len(markers)], color='w', 
                                  markerfacecolor='gray', markersize=10, label=method)
                                  for i, method in enumerate(methods)]
        
        p_value_legend_elements = [Line2D([0], [0], marker='o', color='w', 
                                   markerfacecolor=colors[i], markersize=10, 
                                   label=f'p = {p:.3f}')
                                   for i, p in enumerate(p_vals)]
        
        fig.legend(handles=method_legend_elements, loc='center left', 
                   bbox_to_anchor=(1, 0.7), title="Methods")
        fig.legend(handles=p_value_legend_elements, loc='center left', 
                   bbox_to_anchor=(1, 0.3), title="P-values")
        
        plt.tight_layout()
        
        fig.suptitle(f'Gradient Similarity vs Downstream Accuracy for Memory Selection Methods\n{exp_name}', 
                     fontsize=16, y=1.02)
        
        fig.subplots_adjust(top=0.9, right=0.85)
        
        if plot_ellipse:
            plt.savefig(f'{result_dir}/batch_scatterplot_ellipse_combined_{scale}_{exp_name}.png', bbox_inches='tight', dpi=300)
        else:
            plt.savefig(f'{result_dir}/batch_scatterplot_combined_{scale}_{exp_name}.png', bbox_inches='tight', dpi=300)
        
        plt.close(fig)

# Usage
adapted_batch_scatterplot_grad_dist(aggregated_results, 'dataset_name', results['exp_name'][0], plot_ellipse=False)
# Out:
# /var/folders/9m/3sbbk6pn0ggcr_ynzqxr4ll00000gn/T/ipykernel_6694/1485832460.py:70: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colors = plt.cm.get_cmap('tab10')(np.linspace(0, 1, len(p_vals)))

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.patches import Ellipse
import matplotlib.transforms as transforms
from matplotlib.lines import Line2D

def confidence_ellipse(x, y, ax, n_std=3.0, facecolor='none', **kwargs):
    if x.size != y.size:
        raise ValueError("x and y must be the same size")

    cov = np.cov(x, y)
    pearson = cov[0, 1]/np.sqrt(cov[0, 0] * cov[1, 1])

    ell_radius_x = np.sqrt(1 + pearson)
    ell_radius_y = np.sqrt(1 - pearson)
    ellipse = Ellipse((0, 0), width=ell_radius_x * 2, height=ell_radius_y * 2,
                      facecolor=facecolor, **kwargs)

    scale_x = np.sqrt(cov[0, 0]) * n_std
    mean_x = np.mean(x)

    scale_y = np.sqrt(cov[1, 1]) * n_std
    mean_y = np.mean(y)

    transf = transforms.Affine2D() \
        .rotate_deg(45) \
        .scale(scale_x, scale_y) \
        .translate(mean_x, mean_y)

    ellipse.set_transform(transf + ax.transData)
    return ax.add_patch(ellipse)

def adapted_batch_scatterplot_grad_dist(aggregated_results, dataset_name, exp_name, plot_ellipse=False):
    plt.rcParams['font.family'] = 'Arial'
    plt.rcParams['font.size'] = 12
    
    result_dir = f'gradient_similarity/{dataset_name}/plots'
    if not os.path.exists(result_dir):
        os.makedirs(result_dir)
    
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 10))
    
    methods = aggregated_results['method'].unique()
    p_vals = sorted(aggregated_results['p'].unique())
    
    # Define markers and colors
    markers = ['o', 's', '^', 'D', 'v', '<', '>', 'p', '*', 'h', 'H', '+', 'x', 'd']
    colors = plt.cm.get_cmap('tab10')(np.linspace(0, 1, len(p_vals)))
    
    for ax, metric in zip([ax1, ax2], ['M1', 'M2']):
        for i, method in enumerate(methods):
            for j, p in enumerate(p_vals):
                method_data = aggregated_results[(aggregated_results['method'] == method) & 
                                                 (aggregated_results['p'] == p)]
                
                accs = method_data['M3_task_avg'].values
                accs_std = method_data['M3_task_std'].values
                grad_pts = method_data[f'{metric}_grad_sim_avg'].values
                grad_vars = method_data[f'{metric}_grad_sim_std'].values
                
                obj = ax.scatter(accs, grad_pts, marker=markers[i % len(markers)], c=[colors[j]], 
                                 s=50, zorder=3)
                if plot_ellipse:
                    confidence_ellipse(accs, grad_pts, ax, n_std=1.0, edgecolor=obj.get_edgecolor())
                else:
                    ax.errorbar(accs, grad_pts, xerr=accs_std, yerr=grad_vars, 
                                fmt='none', ecolor=colors[j], alpha=0.5, zorder=2)

        ax.set_xscale('log')
        ax.set_xlim(0.01, 1)
        ax.set_ylim(0, 1.1)
        ax.set_title(f'{metric} Gradient Similarity vs Downstream Accuracy')
        ax.set_ylabel(f'{metric} Gradient Similarity')
        ax.set_xlabel('Downstream Accuracy (M3) - Log Scale')
        
        ax.xaxis.set_minor_locator(plt.LogLocator(base=10, subs=np.arange(1.0, 10.0) * 0.1, numticks=10))
        ax.xaxis.set_minor_formatter(plt.NullFormatter())
        
        ax.set_xticks([0.01, 0.1, 1])
        ax.set_xticklabels(['0.01', '0.1', '1'])

    # Create separate legends for methods and p-values
    method_legend_elements = [Line2D([0], [0], marker=markers[i % len(markers)], color='w', 
                              markerfacecolor='gray', markersize=10, label=method)
                              for i, method in enumerate(methods)]
    
    p_value_legend_elements = [Line2D([0], [0], marker='o', color='w', 
                               markerfacecolor=colors[i], markersize=10, 
                               label=f'p = {p:.3f}')
                               for i, p in enumerate(p_vals)]
    
    # Add legends to the figure
    fig.legend(handles=method_legend_elements, loc='center left', 
               bbox_to_anchor=(1, 0.7), title="Methods")
    fig.legend(handles=p_value_legend_elements, loc='center left', 
               bbox_to_anchor=(1, 0.3), title="P-values")
    
    plt.tight_layout()
    
    # Add the main title with experiment name
    fig.suptitle(f'Gradient Similarity vs Downstream Accuracy for Memory Selection Methods\n{exp_name}', 
                 fontsize=16, y=1.02)
    
    # Adjust the figure size to accommodate the title and legends
    fig.subplots_adjust(top=0.9, right=0.85)
    
    if plot_ellipse:
        plt.savefig(f'{result_dir}/batch_scatterplot_ellipse_combined_log_{exp_name}.png', bbox_inches='tight', dpi=300)
    else:
        plt.savefig(f'{result_dir}/batch_scatterplot_combined_log_{exp_name}.png', bbox_inches='tight', dpi=300)
    plt.show()

adapted_batch_scatterplot_grad_dist(aggregated_results, 'dataset_name', results['exp_name'][0], plot_ellipse=False)
# Out:
# /var/folders/9m/3sbbk6pn0ggcr_ynzqxr4ll00000gn/T/ipykernel_6694/2209999232.py:48: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colors = plt.cm.get_cmap('tab10')(np.linspace(0, 1, len(p_vals)))

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.patches import Ellipse
import matplotlib.transforms as transforms
from matplotlib.lines import Line2D

def confidence_ellipse(x, y, ax, n_std=3.0, facecolor='none', **kwargs):
    if x.size != y.size:
        raise ValueError("x and y must be the same size")

    cov = np.cov(x, y)
    pearson = cov[0, 1]/np.sqrt(cov[0, 0] * cov[1, 1])

    ell_radius_x = np.sqrt(1 + pearson)
    ell_radius_y = np.sqrt(1 - pearson)
    ellipse = Ellipse((0, 0), width=ell_radius_x * 2, height=ell_radius_y * 2,
                      facecolor=facecolor, **kwargs)

    scale_x = np.sqrt(cov[0, 0]) * n_std
    mean_x = np.mean(x)

    scale_y = np.sqrt(cov[1, 1]) * n_std
    mean_y = np.mean(y)

    transf = transforms.Affine2D() \
        .rotate_deg(45) \
        .scale(scale_x, scale_y) \
        .translate(mean_x, mean_y)

    ellipse.set_transform(transf + ax.transData)
    return ax.add_patch(ellipse)


def adapted_batch_scatterplot_grad_dist(aggregated_results, dataset_name, exp_name, plot_ellipse=False):
    plt.rcParams['font.family'] = 'Arial'
    plt.rcParams['font.size'] = 12
    
    result_dir = f'gradient_similarity/{dataset_name}/plots'
    if not os.path.exists(result_dir):
        os.makedirs(result_dir)
    
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 10))
    
    methods = aggregated_results['method'].unique()
    p_vals = sorted(aggregated_results['p'].unique())
    
    # Define markers and colors
    markers = ['o', 's', '^', 'D', 'v', '<', '>', 'p', '*', 'h', 'H', '+', 'x', 'd']
    colors = plt.cm.get_cmap('tab10')(np.linspace(0, 1, len(p_vals)))
    
    for ax, metric in zip([ax1, ax2], ['M1', 'M2']):
        for i, method in enumerate(methods):
            for j, p in enumerate(p_vals):
                method_data = aggregated_results[(aggregated_results['method'] == method) & 
                                                 (aggregated_results['p'] == p)]
                
                accs = method_data['M3_task_avg'].values
                accs_std = method_data['M3_task_std'].values
                grad_pts = method_data[f'{metric}_grad_sim_avg'].values
                grad_vars = method_data[f'{metric}_grad_sim_std'].values
                
                obj = ax.scatter(accs, grad_pts, marker=markers[i % len(markers)], c=[colors[j]], 
                                 s=50, zorder=3)
                if plot_ellipse:
                    confidence_ellipse(accs, grad_pts, ax, n_std=1.0, edgecolor=obj.get_edgecolor())
                else:
                    ax.errorbar(accs, grad_pts, xerr=accs_std, yerr=grad_vars, 
                                fmt='none', ecolor=colors[j], alpha=0.5, zorder=2)

        ax.set_xlim(0, 1)
        ax.set_ylim(0, 1.1)
        ax.set_title(f'{metric} Gradient Similarity vs Downstream Accuracy')
        ax.set_ylabel(f'{metric} Gradient Similarity')
        ax.set_xlabel('Downstream Accuracy (M3)')

    # Create separate legends for methods and p-values
    method_legend_elements = [Line2D([0], [0], marker=markers[i % len(markers)], color='w', 
                              markerfacecolor='gray', markersize=10, label=method)
                              for i, method in enumerate(methods)]
    
    p_value_legend_elements = [Line2D([0], [0], marker='o', color='w', 
                               markerfacecolor=colors[i], markersize=10, 
                               label=f'p = {p:.3f}')
                               for i, p in enumerate(p_vals)]
    
    # Add legends to the figure
    fig.legend(handles=method_legend_elements, loc='center left', 
               bbox_to_anchor=(1, 0.7), title="Methods")
    fig.legend(handles=p_value_legend_elements, loc='center left', 
               bbox_to_anchor=(1, 0.3), title="P-values")
    
    plt.tight_layout()
    
    # Add the main title with experiment name
    fig.suptitle(f'Gradient Similarity vs Downstream Accuracy for Memory Selection Methods\n{exp_name}', 
                 fontsize=16, y=1.02)
    
    # Adjust the figure size to accommodate the title and legends
    fig.subplots_adjust(top=0.9, right=0.85)
    
    if plot_ellipse:
        plt.savefig(f'{result_dir}/batch_scatterplot_ellipse_combined_linear_{exp_name}.png', bbox_inches='tight', dpi=300)
    else:
        plt.savefig(f'{result_dir}/batch_scatterplot_combined_linear_{exp_name}.png', bbox_inches='tight', dpi=300)
    plt.show()

adapted_batch_scatterplot_grad_dist(aggregated_results, 'dataset_name', results['exp_name'][0], plot_ellipse=False)
# Out:
# /var/folders/9m/3sbbk6pn0ggcr_ynzqxr4ll00000gn/T/ipykernel_6694/3882265556.py:49: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colors = plt.cm.get_cmap('tab10')(np.linspace(0, 1, len(p_vals)))

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.patches import Ellipse
import matplotlib.transforms as transforms
from matplotlib.lines import Line2D
import os

def confidence_ellipse(x, y, ax, n_std=3.0, facecolor='none', **kwargs):
    if x.size != y.size:
        raise ValueError("x and y must be the same size")

    cov = np.cov(x, y)
    pearson = cov[0, 1] / np.sqrt(cov[0, 0] * cov[1, 1])

    ell_radius_x = np.sqrt(1 + pearson)
    ell_radius_y = np.sqrt(1 - pearson)
    ellipse = Ellipse((0, 0), width=ell_radius_x * 2, height=ell_radius_y * 2,
                      facecolor=facecolor, **kwargs)

    scale_x = np.sqrt(cov[0, 0]) * n_std
    mean_x = np.mean(x)

    scale_y = np.sqrt(cov[1, 1]) * n_std
    mean_y = np.mean(y)

    transf = transforms.Affine2D() \
        .rotate_deg(45) \
        .scale(scale_x, scale_y) \
        .translate(mean_x, mean_y)

    ellipse.set_transform(transf + ax.transData)
    return ax.add_patch(ellipse)


def adapted_batch_scatterplot_grad_dist(aggregated_results, dataset_name, exp_name, plot_ellipse=False):
    plt.rcParams['font.family'] = 'Arial'
    plt.rcParams['font.size'] = 12
    
    result_dir = f'gradient_similarity/{dataset_name}/plots'
    if not os.path.exists(result_dir):
        os.makedirs(result_dir)
    
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 10))
    
    methods = aggregated_results['method'].unique()
    p_vals = sorted(aggregated_results['p'].unique())
    
    # Define markers
    # markers = ['o', 's', '^', 'D', 'v', '<', '>', 'p', '*', 'h', 'H', '+', 'x', 'd']
    markers = ['o']

    # Use a colormap to assign unique colors to each method
    cmap = plt.get_cmap('tab10')  # This will give us 10 distinct colors
    method_colors = {method: cmap(i % 10) for i, method in enumerate(methods)}
    
    # Adjust circle size scaling (sqrt(p) instead of p) to prevent extreme sizes
    size_scale = 5000  # Adjust this value to control overall circle sizes
    min_size = 25
    
    p_vals = p_vals[:-3]

    for ax, metric in zip([ax1, ax2], ['M1', 'M2']):
        for i, method in enumerate(methods):
            for j, p in enumerate(p_vals):
                method_data = aggregated_results[(aggregated_results['method'] == method) & 
                                                 (aggregated_results['p'] == p)]
                
                accs = method_data['M3_task_avg'].values
                accs_std = method_data['M3_task_std'].values
                grad_pts = method_data[f'{metric}_grad_sim_avg'].values
                grad_vars = method_data[f'{metric}_grad_sim_std'].values
                
                # Use sqrt(p) to control the size of the scatter points to avoid extremes
                size = size_scale * np.sqrt(p)

                size = max(size_scale * np.log(p + 1), min_size)
                
                obj = ax.scatter(accs, grad_pts, marker=markers[i % len(markers)], s=size, 
                                 color=method_colors[method], zorder=3)
                
                if plot_ellipse:
                    confidence_ellipse(accs, grad_pts, ax, n_std=1.0, edgecolor=obj.get_edgecolor())
                else:
                    ax.errorbar(accs, grad_pts, xerr=accs_std, yerr=grad_vars, 
                                fmt='none', ecolor='gray', alpha=0.5, zorder=2)

        ax.set_xscale('log')  # Set x-axis to log scale
        ax.set_yscale('log')  # Set y-axis to log scale
        
        ax.set_xlim(0.001, 1)
        ax.set_ylim(10**-1, 1.1)
        # ax.set_ylim(0.001, 1.1)
        ax.set_title(f'{metric} Gradient Similarity vs Downstream Accuracy')
        ax.set_ylabel(f'{metric} Gradient Similarity')
        ax.set_xlabel('Downstream Accuracy (M3)')

    # Create separate legends for methods and p-values
    method_legend_elements = [Line2D([0], [0], marker=markers[i % len(markers)], color='w', 
                              markerfacecolor=method_colors[method], markersize=10, label=method)
                              for i, method in enumerate(methods)]
    
    p_value_legend_elements = [Line2D([0], [0], marker='o', color='w', 
                               markerfacecolor='gray', markersize=10 * np.sqrt(p * size_scale / 1000), 
                               label=f'p = {p:.3f}')
                               for i, p in enumerate(p_vals)]
    
    # Add legends to the figure
    fig.legend(handles=method_legend_elements, loc='center left', 
               bbox_to_anchor=(1, 0.7), title="Methods")
    fig.legend(handles=p_value_legend_elements, loc='center left', 
               bbox_to_anchor=(1, 0.3), title="P-values")
    
    plt.tight_layout()
    
    # Add the main title with experiment name
    fig.suptitle(f'Gradient Similarity vs Downstream Accuracy for Memory Selection Methods\n{exp_name}', 
                 fontsize=16, y=1.02)
    
    # Adjust the figure size to accommodate the title and legends
    fig.subplots_adjust(top=0.9, right=0.85)
    
    if plot_ellipse:
        plt.savefig(f'{result_dir}/batch_scatterplot_ellipse_combined_log_{exp_name}.png', bbox_inches='tight', dpi=300)
    else:
        plt.savefig(f'{result_dir}/batch_scatterplot_combined_log_{exp_name}.png', bbox_inches='tight', dpi=300)
    plt.show()

# Example call
adapted_batch_scatterplot_grad_dist(aggregated_results, 'dataset_name', results['exp_name'][0], plot_ellipse=False)
